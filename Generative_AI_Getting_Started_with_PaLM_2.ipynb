# %% [markdown]
# <a href="https://colab.research.google.com/github/SridhanyaG/NLPBasicPreprocessingUsingNLTK/blob/main/Generative_AI_Getting_Started_with_PaLM_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative AI - Getting Started with PaLM 2

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-aiplatform==1.26.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.1
#     Uninstalling shapely-2.0.1:
#       Successfully uninstalled shapely-2.0.1
# ...

# %%
from google.cloud import aiplatform
aiplatform.init(project='sascha-playground-doit')

# %% [markdown]
# ## Authentication

# %%
from google.colab import auth
auth.authenticate_user()

# %%
! gcloud config set project sascha-playground-doit
# Out:
# Updated property [core/project].

# %% [markdown]
# ## Text Model

# %%
from vertexai.preview.language_models import TextGenerationModel

# %%
parameters = {
        "temperature": 0.9,
        "max_output_tokens": 512,
        "top_p": .8,
        "top_k": 40,
    }

model = TextGenerationModel.from_pretrained("text-bison@001")

response = model.predict(
        'Give me 5 sightseeing trips for Berlin',
        **parameters,
)
print(f"PaLM 2 Response: {response.text}")
# Out:
# PaLM 2 Response: 1. **The Brandenburg Gate**
#
# The Brandenburg Gate is one of the most iconic landmarks in Berlin. It was built in the 18th century as a symbol of peace and unity. Today, it is a popular tourist destination and a gathering place for protests and celebrations.
#
# 2. **The Reichstag**
#
# The Reichstag is the German parliament building. It was built in the 19th century and has a distinctive glass dome that offers stunning views of the city.
#
# 3. **The Berlin Wall**
#
# The Berlin Wall was a symbol of the division of Germany between East and West. It was built in the 1960s and torn down in 1989. Today, parts of the wall still stand and are a popular tourist attraction.
#
# 4. **The Holocaust Memorial**
#
# The Holocaust Memorial is a sobering reminder of the horrors of the Holocaust. It consists of a field of 2,711 concrete slabs of varying heights.
#
# 5. **The Museum Island**
#
# ...

# %% [markdown]
# ## Chat Model

# %%
from vertexai.preview.language_models import ChatModel, InputOutputTextPair


chat_model = ChatModel.from_pretrained("chat-bison@001")

parameters = {
        "temperature": 0.5,
        "max_output_tokens": 256,
        "top_p": 0.95,
        "top_k": 40,
    }

chat = chat_model.start_chat(
        context="You are an experience tour guide in Berlin that can answer any questions a tourist might ask.",

    )

response = chat.send_message("my name is sascha I would like to visit berlin can you give me your top 2 recommendations?", **parameters)
print(f"PaLM 2 response: {response.text}")
# Out:
# PaLM 2 response: Berlin is a fascinating city with a rich history and culture. There are many things to see and do, but if you only have a few days, I would recommend focusing on the following two areas:
#
# * The Mitte district: This is the heart of Berlin and home to many of the city's most famous landmarks, including the Brandenburg Gate, the Reichstag, and the Berlin Cathedral. It is also a great place to explore the city's vibrant nightlife.
# * The Kreuzberg district: This is a more alternative and bohemian area, with a thriving arts scene and a diverse population. It is also home to some of Berlin's best restaurants and bars.
#
# Of course, these are just a few suggestions. There are many other great places to visit in Berlin, so be sure to do some research and find out what interests you most.

# %%
response = chat.send_message("How do I reach the Brandeburg Gate from the Reichstag?", **parameters)
print(f"PaLM 2 response: {response.text}")
# Out:
# PaLM 2 response: The Brandenburg Gate is about a 10-minute walk from the Reichstag. You can walk down Unter den Linden, which is a beautiful boulevard lined with trees and shops. Alternatively, you can take the U-Bahn (subway) to the Brandenburg Gate station.

# %%
response = chat.send_message("what was my name?", **parameters)
print(f"PaLM 2 response: {response.text}")

# %% [markdown]
# ## Embedding Model

# %%
from vertexai.preview.language_models import TextEmbeddingModel
model = TextEmbeddingModel.from_pretrained("textembedding-gecko@001")

embeddings = model.get_embeddings(["Berlin is a wonderful city"])
for embedding in embeddings:
  embedding = embedding.values
  print(embedding)
  print(f'Embedding Length: {len(embedding)}')
# Out:
# [-0.016155701130628586, 0.03342937305569649, 0.022966867312788963, 0.009329144842922688, -0.0031072620768100023, -0.04412945732474327, 0.017962614074349403, -0.025813637301325798, -0.004535152576863766, -0.013877910561859608, 0.040164489299058914, 0.020243307575583458, 0.06549166887998581, -0.03925406560301781, -0.024825450032949448, -0.034959495067596436, -0.07224523276090622, -0.020745832473039627, -0.004012854304164648, 0.03747688606381416, -0.10253950208425522, -0.00819508358836174, 0.04418101906776428, 0.0074622249230742455, -0.045362405478954315, -0.07200994342565536, 0.023464007303118706, 0.004897432401776314, -0.023092541843652725, 0.03546229749917984, 0.0004683770821429789, 0.0739893689751625, -0.0023864370305091143, -0.045809004455804825, 0.005172580946236849, -0.0005549978814087808, -0.027981095016002655, 0.050406813621520996, 0.01759902760386467, 0.06186512112617493, 0.03160099312663078, -0.00790972076356411, 0.01894662342965603, 0.007391889579594135, 0.008090687915682793
# ...
